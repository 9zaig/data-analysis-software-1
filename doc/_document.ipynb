# %% [markdown]
# # Data analysis software
# ## Team B1

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import glob
from IPython.display import Image

# %%
df = pd.read_csv('./../res/csv/data_analysis.csv')
pd.set_option("display.max_column",15)
df
# Out:
#     Unnamed: 0     Batch Wafer Maskset  TestSite                      Date  \
# 0            0  HY202103   D07   LION1  DCM_LMZC  Mon Jul 15 19:17:03 2019
# 1            1  HY202103   D07   LION1  DCM_LMZC  Mon Jul 15 19:23:09 2019
# 2            2  HY202103   D07   LION1  DCM_LMZC  Mon Jul 15 20:23:41 2019
# 3            3  HY202103   D07   LION1  DCM_LMZC  Mon Jul 15 19:53:07 2019
# 4            4  HY202103   D07   LION1  DCM_LMZC  Mon Jul 15 19:41:08 2019
# ..         ...       ...   ...     ...       ...                       ...
# 93          93  HY202103   D24   LION1  DCM_LMZO  Mon Jun 03 23:27:20 2019
# 94          94  HY202103   D24   LION1  DCM_LMZO  Mon Jun 03 23:18:54 2019
# 95          95  HY202103   D24   LION1  DCM_LMZO  Tue Jun 04 00:09:37 2019
# 96          96  HY202103   D24   LION1  DCM_LMZO  Tue Jun 04 00:26:34 2019
# 97          97  HY202103   D24   LION1  DCM_LMZO  Tue Jun 04 00:18:07 2019
#
# ...

# %% [markdown]
# The table above shows information on each analyzed wafer.

# %% [markdown]
# # Result

# %% [markdown]
# # Fitting (PNG)
# ---
# ![png](https://ifh.cc/g/aMaFmv.jpg)

# %% [markdown]
# Four graph analysis results are stored as a png file.<br>
# First graph is raw data of I-V graph and fitting result. But lmfit part of I-V graph is not properly fitted in some wafers.<br>
# Second graph is spectrum data of wafer.<br>
# Third graph is fitting graph in several orders. You can see from this graph which order fits best.<br>
# Fourth graph is flatten data that spectrum data minus fitted rawe data.

# %% [markdown]
# # CSV
# ---
# ![png](https://ifh.cc/g/x7Vz6m.png)

# %% [markdown]
# The analyzed wafer information is made into a single acceleration file and stored.

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12,8))
ans = plt.subplot(2,2,1)
plt.title('I at -1V [A]')
plt.scatter(df['Wafer'], df['I at -1V [A]'])
ans = plt.subplot(2,2,2)
plt.title('I at 1V [A]')
plt.scatter(df['Wafer'], df['I at 1V [A]'])
ans = plt.subplot(2,2,3)
plt.title('Rsq of IV (1)')
plt.scatter(df['Wafer'], df['Rsq of IV (1)'])
ans = plt.subplot(2,2,4)
plt.title('Max Transmission of Ref.spec.(dB)')
plt.scatter(df['Wafer'], df['Max Transmission of Ref.spec.(dB)'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 plt.figure(figsize=(12,8))
#       2 ans = plt.subplot(2,2,1)
#       3 plt.title('I at -1V [A]')
#
# NameError: name 'plt' is not defined
